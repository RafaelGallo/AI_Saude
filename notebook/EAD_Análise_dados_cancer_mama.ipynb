# %% [markdown]
# # Projeto machine learning - Detecção câncer mama
#
# ![img](https://github.com/RafaelGallo/AI_Saude_out/blob/main/imagem/4241961.jpg?raw=true)
#
# ## Descrição projeto
#
# Este conjunto de dados é derivado da análise de características extraídas de imagens digitalizadas de aspirados com agulha fina (PAAF) de massas mamárias. As características fornecem informações detalhadas sobre os núcleos celulares presentes nas imagens, possibilitando uma análise aprofundada.
#
# O espaço tridimensional referido no contexto deste conjunto de dados é baseado no trabalho de KP Bennett e OL Mangasarian, intitulado "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets," publicado em Optimization Methods and Software em 1992 (vol. 1, pp. 23-34). Esse espaço tridimensional desempenha um papel fundamental na aplicação das técnicas de classificação utilizadas neste conjunto de dados.
#
# **Informações dos Atributos**
#
# O conjunto de dados é composto por três categorias principais de informações:
#
# Número de Identificação
#
# Diagnóstico: Este atributo indica se a massa mamária é maligna (M) ou benigna (B).
#
# **Diciónario dados**
#
# Dez Características de Valor Real para Cada Núcleo Celular: Cada uma dessas características contém informações significativas sobre os núcleos celulares encontrados nas imagens.
#
# a) Raio: Média das distâncias do centro aos pontos do perímetro.
#
# b) Textura: Desvio padrão dos valores da escala de cinza.
#
# c) Perímetro.
#
# d) Área.
#
# e) Suavidade: Variação local nos comprimentos do raio.
#
# f) Compacidade: Calculada como (perímetro ^ 2) / área - 1.0.
#
# g) Concavidade: Gravidade das porções côncavas do contorno.
#
# h) Pontos Côncavos: Número de porções côncavas do contorno.
#
# i) Simetria.
#
# j) Dimensão Fractal: Também conhecida como "aproximação da linha costeira."
#
# **Resumo das Características**
#
# Para cada imagem, a média, o erro padrão e o "pior" ou maior valor (calculado como a média dos três maiores valores) foram determinados para as dez características mencionadas acima, resultando em um total de 30 características. Por exemplo, o campo 3 corresponde ao raio médio, o campo 13 corresponde ao erro padrão do raio, e o campo 23 corresponde ao pior raio.
#
# Todos os valores de características são recodificados com quatro dígitos significativos, garantindo uma representação precisa.
#
# **Valores de Atributos Ausentes**
#
# Não há valores de atributos ausentes neste conjunto de dados, garantindo a integridade das informações.
#
# **Distribuição de Classes**
#
# O conjunto de dados é composto por duas classes principais:
#
# 357 casos benignos.
# 212 casos malignos.
#
# Essas informações fornecem uma visão geral abrangente deste conjunto de dados, permitindo que pesquisadores e profissionais realizem análises de classificação e detecção de câncer de mama com base em características celulares extraídas de imagens de PAAF.
#
# ## Objetivo e Problema
#
# O objetivo deste estudo é desenvolver um modelo de aprendizado de máquina capaz de prever a ocorrência de doenças, com foco especial na detecção de câncer de mama a partir de características extraídas de imagens de aspirados com agulha fina (PAAF) de massas mamárias. Além disso, o objetivo é extrair insights valiosos e significativos a partir dos dados, contribuindo para uma melhor compreensão da doença e de suas características.
#
# **Desenvolvimento de um Modelo de Machine Learning**
#
# A principal meta deste projeto é criar um modelo de aprendizado de máquina robusto e preciso que possa analisar os dados dessas imagens e fazer previsões precisas sobre a presença da doença. Para alcançar esse objetivo, serão aplicadas técnicas de processamento de imagens e algoritmos de aprendizado de máquina avançados. O modelo será treinado com base nas características dos núcleos celulares presentes nas imagens para realizar diagnósticos precisos e apoiar profissionais de saúde na tomada de decisões.
#
# **Extração de Insights Relevantes**
#
# Além da construção do modelo de previsão, outro objetivo fundamental é extrair insights relevantes a partir do conjunto de dados. Isso envolve a análise detalhada das características celulares e sua relação com o diagnóstico de câncer de mama. A identificação de padrões, correlações e características críticas permitirá uma compreensão mais profunda da doença e pode levar a avanços na área médica. A interpretação dos resultados do modelo também desempenha um papel crucial na extração desses insights.
#
# **Contribuição para a Compreensão da Doença**
#
# Este estudo não só busca criar um modelo de machine learning para prever a doença, mas também visa contribuir para uma compreensão mais ampla do câncer de mama. A análise das características celulares e a identificação de fatores-chave podem lançar luz sobre a progressão da doença, fatores de risco e potenciais tratamentos. Esses insights têm o potencial de impactar positivamente a prática clínica e a pesquisa médica relacionada ao câncer de mama.
#
# Em resumo, este projeto tem como objetivo central o desenvolvimento de um modelo de machine learning para a previsão de doenças, com ênfase na detecção de câncer de mama, ao mesmo tempo em que busca a extração de insights significativos para ampliar o conhecimento sobre a doença e suas características.
#
# # Observação
#
# Este projeto de machine learning aplicado à saúde não deve ser utilizado com o objetivo de simplesmente obter resultados. Em vez disso, é essencial enfatizar que a sua aplicação deve visar benefícios significativos e éticos, indo além da mera busca por resultados.
#
# A aplicação de machine learning na área de saúde requer uma abordagem responsável e cuidadosa, com foco na qualidade e na segurança dos resultados obtidos. O propósito fundamental não é apenas gerar resultados !

# %% [markdown]
# ## Importação bibliotecas

# %%
# Importação das bibliotecas 

# Bibliotecas sistema
import re
import unicodedata
import itertools

# Biblioteca para manipulação de arquivos
import pandas as pd
import numpy as np 

# Visualização de dados
import plotly
import seaborn as sns
import matplotlib as m
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly.express as px
from matplotlib import pyplot as plt

# Carregar as versões das bibliotecas
import watermark

# Versões das bibliotecas
# %reload_ext watermark
# %watermark -a "Versões das bibliotecas" --iversions

# Configuração para os gráficos largura e layout dos graficos
sns.set_theme(style='whitegrid')
plt.style.use('ggplot')

plt.rcParams["figure.figsize"] = (20, 10)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

m.rcParams['axes.labelsize'] = 15
m.rcParams['xtick.labelsize'] = 15
m.rcParams['ytick.labelsize'] = 15
m.rcParams['text.color'] = 'k'

# Warnings retirar alertas 
import warnings
warnings.filterwarnings("ignore")

# Versão do python
from platform import python_version
print('Versão python neste Jupyter Notebook:', python_version())
# Out:
# Author: Versões das bibliotecas
#
# matplotlib: 3.7.2
# re        : 2.2.1
# watermark : 2.4.3
# seaborn   : 0.12.2
# numpy     : 1.23.5
# pandas    : 1.5.3
# plotly    : 5.16.1
#
# Versão python neste Jupyter Notebook: 3.9.13

# %% [markdown]
# # Dataset

# %%
# Dataset
data = pd.read_csv("data.csv")
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  area_se  smoothness_se  compactness_se  concavity_se  concave points_se  symmetry_se  fractal_dimension_se  radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst
_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# Gráfico barras
sns.countplot(data=data, x='diagnosis')  
plt.title("Contagem de diagnósticos")

# Define o nome do arquivo de saída e o formato (PNG no exemplo)
output_file = "contagem_diagnosticos_ggplot.png"
plt.savefig(output_file, format="png")

# Opcional para mostrar o gráfico na tela
plt.show()

# %%
# Agrupe os dados por 'diagnosis' e calcule a média do 'radius_mean'
grouped_data = data.groupby('diagnosis')['texture_mean'].mean()

# Crie um gráfico de barras
plt.figure(figsize=(8, 6))
grouped_data.plot(kind='bar', color=['lightcoral', 'lightseagreen'])
plt.title('Média textura por diagnóstico')
plt.ylabel('Total')
plt.xlabel("Diagnóstico")
plt.xticks(range(len(grouped_data.index)), grouped_data.index, rotation=0)

# Define o nome do arquivo de saída e o formato (PNG no exemplo)
output_file = "Média textura por diagnóstico.png"
plt.savefig(output_file, format="png")

# Opcional para mostrar o gráfico na tela
plt.show()

# %%
# Agrupe os dados por 'diagnosis' e calcule a média do 'radius_mean'
grouped_data = data.groupby('diagnosis')['radius_mean'].mean()

# Crie um gráfico de barras
plt.figure(figsize=(18, 6))
grouped_data.plot(kind='bar', color=['lightcoral', 'lightseagreen'])
plt.title('Média Diagnóstico')
plt.ylabel('Média')
plt.xlabel("Diagnóstico")
plt.xticks([0, 1], ['Benigno (B)', 'Maligno (M)'], rotation=0)

# Define o nome do arquivo de saída e o formato (PNG no exemplo)
output_file = "Média_Diagnóstico.png"
plt.savefig(output_file, format="png")

# Opcional para mostrar o gráfico na tela
plt.show()

# %%
# 7. Relação entre 'diagnosis' e 'radius_mean'
plt.figure(figsize=(10, 6))
sns.boxplot(x='diagnosis', y='radius_mean', data=data)
plt.title('Relação entre Diagnosis e Raio Médio')
plt.ylabel('Total')
plt.xlabel("Diagnóstico")

# Define o nome do arquivo de saída e o formato (PNG no exemplo)
output_file = "Relação_Diagnosis_Raio_Médio.png"
plt.savefig(output_file, format="png")

# Opcional para mostrar o gráfico na tela
plt.show()

# %%
# 5. Correlação entre as variáveis
data_corr = data.corr()

f,ax = plt.subplots(figsize=(20, 20))
sns.heatmap(data_corr, annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# Define o nome do arquivo de saída e o formato (PNG no exemplo)
output_file = "data_corr.png"
plt.savefig(output_file, format="png")

# Opcional para mostrar o gráfico na tela
plt.show()

# %%
# 6. Distribuição de algumas variáveis
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.histplot(data['radius_mean'], bins=20, kde=True)
plt.title('Distribuição do raio médio')

plt.subplot(1, 2, 2)
sns.histplot(data['texture_mean'], bins=20, kde=True)
plt.title('Distribuição da textura média')

# Define o nome do arquivo de saída e o formato (PNG no exemplo)
output_file = "Distribuição_variáveis.png"
plt.savefig(output_file, format="png")

# Opcional para mostrar o gráfico na tela
plt.show()

# %%
# Histrograma geral
data.hist(bins = 40, figsize=(20, 20))

# Define o nome do arquivo de saída e o formato (PNG no exemplo)
output_file = "Distribuição_variáveis_2.png"
plt.savefig(output_file, format="png")

# Opcional para mostrar o gráfico na tela
plt.show()

# %%
# Gráfico pairplot
plt.figure(figsize=(14, 6))

sns.pairplot(data, 
             hue='diagnosis', 
             vars=['radius_mean', 
                   'texture_mean', 
                   'area_mean', 
                   'smoothness_mean'])

# Define o nome do arquivo de saída e o formato (PNG no exemplo)
output_file = "pairplot.png"
plt.savefig(output_file, format="png")

# Opcional para mostrar o gráfico na tela
plt.show()

# %%
# Gráfico subplots histplot
fig , axes = plt.subplots(nrows=3, ncols=3 , figsize = (20, 22))

ax = sns.histplot(data["radius_mean"] , ax=axes[0, 0])
ax = sns.histplot(data["texture_mean"] ,  ax=axes[0, 1])
ax = sns.histplot(data["perimeter_mean"] , ax=axes[0, 2])
ax = sns.histplot(data["area_mean"], ax=axes[1, 0] )
ax = sns.histplot(data["smoothness_mean"] , ax=axes[1, 1] )
ax = sns.histplot(data["compactness_mean"] , ax=axes[1, 2] )
ax = sns.histplot(data["symmetry_mean"] , ax=axes[2, 0])
ax = sns.histplot(data["fractal_dimension_mean"], ax=axes[2, 1])
ax = sns.histplot(data["radius_se"], ax=axes[2, 2])

# Define o nome do arquivo de saída e o formato (PNG no exemplo)
output_file = "subplots_histplot.png"
plt.savefig(output_file, format="png")

# Opcional para mostrar o gráfico na tela
plt.show()

# %%
# Selecione as variáveis para os gráficos de boxplot
selected_features = ["radius_mean", 
                     "texture_mean", 
                     "perimeter_mean", 
                     "area_mean", 
                     "smoothness_mean", 
                     "compactness_mean",
                     "symmetry_mean",
                     "fractal_dimension_mean", 
                     "radius_se"]

# Matriz de gráficos de boxplot
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(20, 22))
for i, feature in enumerate(selected_features):
    row, col = divmod(i, 3)
    ax = sns.boxplot(x="diagnosis", y=feature, data=data, ax=axes[row, col])
    ax.set_title(f'Boxplot de {feature}')

# Define o nome do arquivo de saída e o formato (PNG no exemplo)
output_file = "subplots_boxplot.png"
plt.savefig(output_file, format="png")

# Opcional para mostrar o gráfico na tela
plt.show()

# %%
# Gráfico scatterplot
plt.figure(figsize=(14, 6))
sns.scatterplot(x="area_mean", y="texture_mean", data = data, hue="diagnosis")
plt.title("Gráfico scatterplot - Diagnósticos")
plt.xlabel("Diagnósticos por porporção")
plt.ylabel("Total")

# Define o nome do arquivo de saída e o formato (PNG no exemplo)
output_file = "grafico_scatterplot.png"
plt.savefig(output_file, format="png")

# Opcional para mostrar o gráfico na tela
plt.show()

# %%
# Gráfico regressão
plt.figure(figsize=(14, 6))
sns.regplot(x="perimeter_mean", y="area_mean", data = data)
plt.title("Gráfico regressão - Diagnósticos")
plt.xlabel("Diagnósticos por porporção")
plt.ylabel("Total")

# Define o nome do arquivo de saída e o formato (PNG no exemplo)
output_file = "Gráfico_regressão.png"
plt.savefig(output_file, format="png")

# Opcional para mostrar o gráfico na tela
plt.show()
